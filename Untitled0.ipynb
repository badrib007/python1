# %%
X=int(input("enter the value of X : "))
Y=int(input ("enter the value of Y : "))
print("addition of X and Y :",X+Y)

print(" multiplication of X and Y :",X*Y)

print("subraction of X and Y :",X-Y)

print("division of X and Y :",X/Y)
# Out:
# enter the value of X : 100
# enter the value of Y : 200
# addition of X and Y : 300
#  multiplication of X and Y : 20000
# subraction of X and Y : -100
# division of X and Y : 0.5

# %% [markdown]
# # FUNDAMENTAL DATATYPES
# * int
# * float
# * complex
# * boolean
# * string

# %%
 x =12
 y=20.2
 z=5+6j
 print(type(x))
 print(type(y))
 print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
c=complex(2,5)
print(c)
# Out:
# (2+5j)

# %%
c1=5+4j
c2=6+7j
print("addition of complex values",c1+c2)
print("multiplication of complex values",c1*c2)
print("subraction of complex values",c1-c2)
print("division of complex values",c1/c2)
# Out:
# addition of complex values (11+11j)
# multiplication of complex values (2+59j)
# subraction of complex values (-1-3j)
# division of complex values (0.6823529411764705-0.12941176470588237j)

# %%
#boolean
x=6
y=7
x<y


#string
s1="abd"
s2="dfg"
print(type(s1))
print(type(s2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
i=100
print(type(i))
s1=str(i)
print(type(s1))
f1=float(i)
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
#length
a="abcd"
print(len(str(a)))
# Out:
# 4

# %%
n1= 100 # single variable assignment
a=b=c=20 #multiple variable assignment
a1,b1,c1= 123,234,345
print(n1)
print(a,b,c)
print(a1,b1,c1)
# Out:
# 100
# 20 20 20
# 123 234 345

# %% [markdown]
# # Presendence Of Arth Operators
# * Paranthesis
# * Power
# * Multiplication
# * Addition

# %%
 x= 1+2 ** 3/4*5
 print(x)
# Out:
# 11.0

# %% [markdown]
# # Operators
# ## Arthimetic Operators
# * +
# * -
# * *
# * /
# * %
# * **
# * //

# %% [markdown]
# # Relational Operators
# * ==,!=,<,>,<=,>=

# %% [markdown]
# # Logical Operators
# * and
# * or
# * not

# %%
i=100
a1=(i>15) and (i>76)
a2=(i>567) and (i>3456)
print(a1)
print(a2)
print(not i)
# Out:
# True
# False
# False

# %% [markdown]
# # Membership Operator
# * in
# * not in

# %%
str1 = "abc"
print('a' in str1)
print('a' not in str1)
# Out:
# True
# False

# %% [markdown]
# # Control Flow Statements
# * conditional statements
# *looping statements
# # if -else statement
# * syntax
#
#
#     if condition:
#
#             statements
#
#     else
#
#             statements

# %%
#check the given number is even or odd
n=int(input("enter a number"))
if n%2 == 0:
   print("even")
else:
   print("odd")
# Out:
# enter a number5
# odd

# %%
#check the given number is perfectly multiple of 3 and  5
n= int(input("enter a number:"))
if n%3== 0 and n%5==0:
    print("yes")
else:
    print("no")
# Out:
# enter a number:15
# yes

# %%
#check the given number is  positive,negative or zero
A=int(input("enter the number"))
if n<0:
    print("the given number is positive")
# Out:
# enter the number56
